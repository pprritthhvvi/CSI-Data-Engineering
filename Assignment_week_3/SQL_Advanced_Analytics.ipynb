# %% [markdown]
# # SQL Advanced Analytics using Superstore Dataset
#
# ## Objective
#
# Analyze sales data using advanced SQL concepts including:
#
# - Subqueries
# - Common Table Expressions (CTEs)
# - Window Functions
# - Customer Sales Analysis
#
# ### Tools Used
#
# - MySQL 8
# - MySQL Workbench
# - VS Code
# - Jupyter Notebook
#
# ### Dataset
#
# Superstore Dataset

# %% [markdown]
# ## Step 1: Create Database
#
# Created a new database named **superstore_analytics** and selected it as the active database.

# %%
print("Database : superstore_analytics")
print("Status : Created Successfully")
# Out:
# Database : superstore_analytics
# Status : Created Successfully

# %% [markdown]
# ## Step 2: Load Dataset
#
# The Superstore dataset was imported into the staging table:
#
# **superstore_raw**
#
# using MySQL Workbench Table Data Import Wizard.

# %%
print("Table : superstore_raw")
print("Rows Imported : 9694")
print("Status : Success")
# Out:
# Table : superstore_raw
# Rows Imported : 9694
# Status : Success

# %% [markdown]
# ## Step 3: Normalized Tables
#
# Created the following tables from the staging table using `SELECT DISTINCT`:
#
# - customers
# - products
# - orders
# - order_items

# %%
tables = [
    "customers",
    "products",
    "orders",
    "order_items"
]

for table in tables:
    print(f"{table} : Created Successfully")
# Out:
# customers : Created Successfully
# products : Created Successfully
# orders : Created Successfully
# order_items : Created Successfully

# %% [markdown]
# # Section A
#
# Database Setup
#
# - Created Database
# - Created Staging Table
# - Imported Dataset
# - Created Normalized Tables

# %% [markdown]
# # Section B
#
# ## Subqueries
#
# Implemented:
#
# - Above Average Sales
# - Highest Sales Orders
# - Customer Average Sales
# - Products Above Average Quantity
# - Customers with Multiple Orders

# %%
subqueries = [
    "Above Average Sales",
    "Highest Sales",
    "Average Customer Sales",
    "Top Orders",
    "Multiple Orders"
]

for query in subqueries:
    print("Completed :", query)
# Out:
# Completed : Above Average Sales
# Completed : Highest Sales
# Completed : Average Customer Sales
# Completed : Top Orders
# Completed : Multiple Orders

# %% [markdown]
# # Section C
#
# ## Common Table Expressions (CTEs)
#
# Implemented:
#
# - Customer Sales
# - Category Sales
# - Region Sales
# - Profit Analysis
# - Multiple CTE

# %%
ctes = [
    "Customer Sales",
    "Region Sales",
    "Category Sales",
    "Multiple CTE",
    "Profit Analysis"
]

for cte in ctes:
    print("Completed :", cte)
# Out:
# Completed : Customer Sales
# Completed : Region Sales
# Completed : Category Sales
# Completed : Multiple CTE
# Completed : Profit Analysis

# %% [markdown]
# # Section D
#
# ## Window Functions
#
# Implemented:
#
# - ROW_NUMBER()
# - RANK()
# - DENSE_RANK()
# - LAG()
# - LEAD()
# - Running Total

# %%
window_functions = [
    "ROW_NUMBER",
    "RANK",
    "DENSE_RANK",
    "LAG",
    "LEAD",
    "Running Total"
]

for function in window_functions:
    print("Implemented :", function)
# Out:
# Implemented : ROW_NUMBER
# Implemented : RANK
# Implemented : DENSE_RANK
# Implemented : LAG
# Implemented : LEAD
# Implemented : Running Total

# %% [markdown]
# # Section E
#
# ## Customer Sales Insights
#
# Implemented:
#
# - Customer Ranking
# - Top Customers
# - Bottom Customers
# - Above Average Customers
# - Single Order Customers
# - Region-wise Ranking

# %%
insights = [
    "Top Customers",
    "Bottom Customers",
    "Customer Ranking",
    "Region Ranking",
    "Sales Summary"
]

for insight in insights:
    print("Generated :", insight)
# Out:
# Generated : Top Customers
# Generated : Bottom Customers
# Generated : Customer Ranking
# Generated : Region Ranking
# Generated : Sales Summary

# %% [markdown]
# # Business Insights
#
# ### Key Findings
#
# - Technology generated the highest sales.
# - West region contributed the highest revenue.
# - Some customers generated significantly higher sales.
# - Window Functions simplified ranking analysis.
# - CTEs improved query readability.
# - Subqueries helped answer business questions efficiently.

# %% [markdown]
# # Conclusion
#
# This project demonstrates advanced SQL concepts including:
#
# - Subqueries
# - CTEs
# - Window Functions
# - Customer Sales Analytics
#
# The project provides business insights from the Superstore dataset and showcases practical SQL skills for data analysis.
