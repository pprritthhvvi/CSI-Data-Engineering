# %% [markdown]
# # Local Data Pipeline
#
# ## Azure Data Factory Alternative
#
# This project simulates Azure Data Factory activities using Python.

# %% [markdown]
# ## Project Objective
#
# Create an end-to-end ETL pipeline consisting of:
#
# - Get Metadata
# - Copy Data
# - Validation
# - Pipeline Automation

# %%
print("Pipeline Created Successfully")
# Out:
# Pipeline Created Successfully

# %%
print("""
Source Folder
      │
      ▼
Get Metadata
      │
      ▼
Copy Data
      │
      ▼
Destination Folder
      │
      ▼
Validation
""")
# Out:
# Source Folder
#       │
#       ▼
# Get Metadata
#       │
#       ▼
# Copy Data
#       │
#       ▼
# Destination Folder
#       │
#       ▼
# Validation

# %% [markdown]
# # Activities Completed
#
# - Get Metadata
# - Copy Data
# - Validation
# - Pipeline Automation

# %%
activities = [
    "Get Metadata",
    "Copy Data",
    "Validation",
    "Pipeline"
]

for activity in activities:
    print(f"Completed: {activity}")
# Out:
# Completed: Get Metadata
# Completed: Copy Data
# Completed: Validation
# Completed: Pipeline

# %% [markdown]
# # Conclusion
#
# The project successfully simulates an Azure Data Factory pipeline using Python and local storage.
#
# The pipeline automatically:
#
# - Reads metadata
# - Copies the file
# - Validates the copied file
# - Generates output
